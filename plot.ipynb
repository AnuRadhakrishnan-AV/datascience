# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# plot1

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)

# plot2

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
# plot1

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,1)
plt.plot(x,y)
plt.title('FIRST')

# plot2

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,3,2)
plt.plot(x,y)
plt.title('SECOND')

# plot3
x=np.array([0,1,2,3])
y=np.array([10,2,3,4])
plt.subplot(2,3,3)
plt.plot(x,y)
plt.title('THIRD')


# plot4
x=np.array([0,1,2,3])
y=np.array([10,2,3,8])
plt.subplot(2,3,4)
plt.plot(x,y)
plt.title('FOURTH')


# plot1+4
x=np.array([0,1,2,3])
y=np.array([10,9,2,8])
plt.subplot(2,3,5)
plt.plot(x,y)
plt.title('FIFTH')


# plot2+4
x=np.array([0,1,2,3])
y=np.array([10,9,2,8])
plt.subplot(2,3,6)
plt.plot(x,y)
plt.title('SIXTH')
plt.suptitle('PLOTTING')
plt.show()

# %%
#super title
import matplotlib.pyplot as plt
import numpy as np

#plot1
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("SALES")

#plot2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])

plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("INCOME")
plt.suptitle("MY SHOPE")
plt.show()

# %%
h=np.array([1,2,3,8,9,12,11,3,7,8,9,10,20,30,40,20,30,20,1,30])
w=np.array([100,23,30,80,39,42,31,93,70,82,99,10,20,30,40,20,30,20,10,30])
plt.scatter(h, w,color="green")
plt.show()

# %%
x=[2,3,4,7,8,9,2,8,11,12,13,19,10,18,17]
y=[88,90,30,20,18,20,70,27,18,30,48,10,71,29,28]
plt.bar(x,y,color="red")
plt.title("first bar graph")
plt.show()

# %%
x=[2,3,4,7,8,9,2,8,11,12,13,19,10,18,17]
y=[88,90,30,20,18,20,70,27,18,30,48,10,71,29,28]
plt.barh(x,y,color="red")
plt.title("first bar graph")
plt.show()

# %%
x=np.random.normal(170,10,250)
print(x)
plt.hist(x,color='pink')
plt.show()
# Out:
# [173.74524729 173.66545153 191.47531896 171.30032156 167.53562617
#  184.70651255 163.66003023 165.51321213 173.6660217  201.38601249
#  162.11925719 171.77385659 160.44369505 180.19238981 177.46552413
#  168.24751991 155.8255933  179.46310763 168.98997718 163.67753863
#  151.85007682 160.5278224  163.41911468 175.0981725  162.88465222
#  150.7266501  184.71701277 174.68748129 182.69242889 183.22075966
#  187.55559855 155.35935653 169.47286438 158.94990194 165.08673731
#  145.71430916 174.37831655 168.69962075 170.25670432 156.24249395
#  168.49924961 182.06779682 180.17748583 171.00002651 170.4603282
#  157.33339668 164.79154638 171.19685205 183.68707266 172.168954
#  171.79596327 160.89418977 183.94281195 178.69371775 168.60846952
#  176.77554036 163.76961891 166.53375279 165.12963179 177.38048039
#  166.85903317 187.64578264 165.94757856 158.46106401 163.36581796
#  156.59182294 167.47763828 179.33100604 176.01608052 188.61609208
# ...

# %%
y=np.array([20,30,40,50])
name=['a','b','c','d']
fruits=['apple','banana','cherry','orange']
plt.pie(y,labels=fruits,startangle=40,explode=[0.1,0.1,0.1,0.1],shadow=True)
plt.legend(title="four name:")
plt.show()

# %%
y=np.array([20,30,40,50])
fruits=['apple','banana','cherry','orange']
plt.pie(y,labels=fruits,startangle=70)
plt.show()

# %%
y=np.array([20,30,40,50])
fruits=['apple','banana','cherry','orange']
plt.pie(y,labels=fruits,startangle=70)
plt.show()
