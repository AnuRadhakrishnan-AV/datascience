# %%
import pandas as pd

# %%
data=pd.read_csv("reported_hospital_capacity_admissions_facility_level_weekly_average_timeseries_20210103.csv")

# %%
data
# Out:
#                                               hospital_pk collection_week  \
# 0       df2363988746840134806aa7b2accf9c89259601776986...      2020-12-25
# 1       3b081d5ef1c552538e4af4aa593a857bb922a4f364a412...      2020-12-25
# 2                                                  452193      2020-12-25
# 3       aab2bb3ab769da90baf57242c96ec481afb5ec6a233784...      2020-12-25
# 4       9922a3f069ff4686fe467885206fb1172f609233cfe517...      2020-12-25
# ...                                                   ...             ...
# 106954                                             400130      2020-07-31
# 106955                                             400115      2020-07-31
# 106956                                             400110      2020-07-31
# 106957                                             480002      2020-07-31
# 106958                                             480001      2020-07-31
#
#        state     ccn                           hospital_name  \
# ...
